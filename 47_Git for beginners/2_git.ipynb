# %%
cd G:\My Drive\AL-ML by Krish Naik
# Out:
# G:\My Drive\AL-ML by Krish Naik

# %%
# !git log
# Out:
# commit 04126a8635415237c019fff9aafe2584a92ba921
# Author: mehta-g1 <vikash.kumarmehta.bca.2023@mitmeerut.ac.in>
# Date:   Sat Aug 15 11:39:44 2026 +0530
#
#     g
#
# commit 4bcc3827a6dc929024de8e063b054d8f31eeeda0
# Author: mehta-g1 <vikash.kumarmehta.bca.2023@mitmeerut.ac.in>
# Date:   Sat Aug 15 11:39:19 2026 +0530
#
#     k
#
# commit 0efcaa03d9656d3b90692c2b5c1fee8c7b196fba
# Author: mehta-g1 <vikash.kumarmehta.bca.2023@mitmeerut.ac.in>
# Date:   Sat Aug 15 11:24:26 2026 +0530
#
#     new commit1
#
# commit 372e4420012cc43e2ffe791d4c6010d11ec89c21
# Author: mehta-g1 <vikash.kumarmehta.bca.2023@mitmeerut.ac.in>
# Date:   Sat Aug 15 11:24:10 2026 +0530
#
#     new commit
#
# commit c3604408fbd0d6dee590991b54c6f39bf77b6b20
# Author: mehta-g1 <vikash.kumarmehta.bca.2023@mitmeerut.ac.in>
# Date:   Sat Aug 15 11:23:24 2026 +0530
#
#     new commit
#
# commit 521725d38c9fe5ee67fa6dca84c8db4faec4f726
# Author: mehta-g1 <vikash.kumarmehta.bca.2023@mitmeerut.ac.in>
# ...

# %%
# !git --version
# Out:
# git version 2.55.0.windows.3
