# %% [markdown]
# ## SQL and SQlite3
#
# SQL (Structured Query Language) is a standard language for managing and manipulating relational databases. SQLite is a self-contained, serverless, and zero-configuration database engine that is widely used for embedded database systems. In this lesson, we will cover the basics of SQL and SQLite, including creating databases, tables, and performing various SQL operations.

# %%
import sqlite3

# %%
connection = sqlite3.connect("test.db")
connection

# %%
cur = connection.cursor()

# %%
# CREATE A TABLE
cur.execute('''
    CREATE TABLE IF NOT EXISTS Employee(
        id INT PRIMARY KEY,
        name VARCHAR(50) NOT NULL,
        age INT,
        department VARCHAR(50)
    )
''')

# COMMIT THE CHANGES


connection.commit()

# %%
# Insert the data

cur.execute('''
    INSERT INTO Employee(id, name, age, department)
    VALUES (99, 'Vikash', 22, 'Computer Application')

''')

cur.execute('''
    INSERT INTO Employee(id, name, age, department)
    VALUES (100, 'bob', 25, 'Engineering')

''')

cur.execute('''
    INSERT INTO Employee(id, name, age, department)
    VALUES (101, 'Charlie', 34, 'Machanical')

''')

# commit the changes
connection.commit()

# %%
# Query the data from table

cur.execute("SELECT * FROM Employee")

rows = cur.fetchall()

# print the data

for row in rows:
    print(row)
# Out:
# (99, 'Vikash', 22, 'Computer Application')
# (100, 'bob', 25, 'Engineering')
# (101, 'Charlie', 34, 'Machanical')

# %%
connection = sqlite3.connect('sales_data.db')
cur = connection.cursor()

cur.execute('''
    CREATE TABLE IF NOT EXISTS sales(
        id INT PRIMARY KEY,
        date TEXT NOT NULL,
        product TEXT NOT NULL,
        sales INT,
        region TEXT
    )
''')
sales_data = [
    ('2023-01-01', 'Product1', 100, 'North'),
    ('2023-01-02', 'Product2', 200, 'South'),
    ('2023-01-03', 'Product1', 150, 'East'),
    ('2023-01-04', 'Product3', 250, 'West'),
    ('2023-01-05', 'Product2', 300, 'North')
]

cur.executemany('''
    INSERT INTO sales(date, product, sales, region)
    VALUES(?,?,?,?)
''', sales_data)

connection.commit()

# %%
cur.execute("SELECT * FROM sales")

rows = cur.fetchall()

# print the data

for row in rows:
    print(row)
# Out:
# (None, '2023-01-01', 'Product1', 100, 'North')
# (None, '2023-01-02', 'Product2', 200, 'South')
# (None, '2023-01-03', 'Product1', 150, 'East')
# (None, '2023-01-04', 'Product3', 250, 'West')
# (None, '2023-01-05', 'Product2', 300, 'North')

# %%
# close the conneciton

connection.close()
